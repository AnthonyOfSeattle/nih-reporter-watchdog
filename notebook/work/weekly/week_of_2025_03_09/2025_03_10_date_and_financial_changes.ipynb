# %%
import duckdb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from datetime import datetime, timedelta

# %% [markdown]
# # 1. Retrieve entries where the Project End and Award Amount have changed

# %% [markdown]
# This first set of data focuses on grants which do not have an activity code that starts with F. Later on in this notebook, I pull out F grants, but I believe some date and funding changes for F type grants may reflect graduations. Date and funding changes for non-training grants may be rarer.

# %%
data = duckdb.query(
    """
    SELECT new_data.date_added,
           new_data.appl_id,
           new_data.project_num,
           new_data.project_num_split.activity_code activity_code,
           new_data.project_title,
           new_data.organization.org_name,
           old_data.project_start_date,
           new_data.project_end_date new_project_end_date,
           old_data.project_end_date old_project_end_date,
           old_data.budget_start,
           new_data.budget_end new_budget_end_date,
           old_data.budget_end old_budget_end_date,
           new_data.award_amount new_award_amount,
           old_data.award_amount old_award_amount,
           new_data.award_amount - old_data.award_amount award_amount_change
    FROM read_json('../../../data/json/projects/year_added=202[345]/*/*') AS new_data
    INNER JOIN read_json('../../../data/json_2025_03_03/projects/year_added=202[345]/*/*') AS old_data
      ON new_data.appl_id = old_data.appl_id
    WHERE new_data.project_end_date < old_data.project_end_date
      AND new_award_amount < old_award_amount
      AND new_data.project_num_split.activity_code NOT LIKE 'F%'
    ORDER BY new_project_end_date DESC
    """
).to_df()

data.to_csv(
    "/home/jovyan/public/weekly/week_of_2025_03_09/data/project_changes_level_1_project_end_and_award_changes.csv",
    index=False
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# For convenience, below I will write out the projects which have new project end dates after the last innauguration in a more human readable format.

# %%
select = data.new_project_end_date >= datetime(2025, 1, 20)
for ind, row in data[select].iterrows():
    print(row.project_num, row.appl_id)
    print(row.org_name)
    print(row.project_title)
    print("-" * 75)
    print(f"Project Start:      {row.project_start_date}  --  Budget Start:      {row.budget_start}")
    print(f"Old Project End:    {row.old_project_end_date}  --  Old Budget End:    {row.old_budget_end_date}")
    print(f"New Project End:    {row.new_project_end_date}  --  New Budget End:    {row.new_budget_end_date}")
    print("-" * 75)
    print(f"Old Award Amount:   {row.old_award_amount}")
    print(f"New Award Amount:   {row.new_award_amount}")
    print(f"Award Change:      {row.new_award_amount - row.old_award_amount}")
    print("-" * 75)
    print("\n")
# Out:
# 5R01DK129239-03 10689869
# UNIVERSITY OF ALABAMA AT BIRMINGHAM
# Mitochondrial-based Determinants of Sex Differences in Acute Kidney Injury
# ---------------------------------------------------------------------------
# Project Start:      2021-09-15 12:09:00  --  Budget Start:      2023-07-01 12:07:00
# Old Project End:    2025-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   222750
# New Award Amount:   221521
# Award Change:      -1229
# ---------------------------------------------------------------------------
#
#
# 5R01AI171984-03 10910038
# VAN ANDEL RESEARCH INSTITUTE
# The roles of genetics, hormones, and gender in sexually dimorphic immune response
# ---------------------------------------------------------------------------
# Project Start:      2022-09-01 12:09:00  --  Budget Start:      2024-09-01 12:09:00
# Old Project End:    2026-08-31 12:08:00  --  Old Budget End:    2025-08-31 12:08:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   610938
# New Award Amount:   172839
# Award Change:      -438099
# ---------------------------------------------------------------------------
#
#
# 1R01HD115881-01 10944419
# EMORY UNIVERSITY
# Microbiome mediated effects of gender affirming hormone therapy in mice
# ---------------------------------------------------------------------------
# Project Start:      2024-08-06 12:08:00  --  Budget Start:      2024-08-06 12:08:00
# Old Project End:    2029-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   735113
# New Award Amount:   377894
# Award Change:      -357219
# ---------------------------------------------------------------------------
#
#
# 5R01HD111650-02 11000334
# UNIVERSITY OF CALIFORNIA, SAN DIEGO
# Androgen effects on the reproductive neuroendocrine axis
# ---------------------------------------------------------------------------
# Project Start:      2023-12-12 12:12:00  --  Budget Start:      2024-12-01 12:12:00
# Old Project End:    2028-11-30 12:11:00  --  Old Budget End:    2025-11-30 12:11:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   581671
# New Award Amount:   193890
# Award Change:      -387781
# ---------------------------------------------------------------------------
#
#
# 5R21HD107311-02 10697301
# SEATTLE CHILDREN'S HOSPITAL
# An intervention to promote healthy relationships among transgender and gender expansive youth
# ---------------------------------------------------------------------------
# Project Start:      2022-09-05 12:09:00  --  Budget Start:      2023-09-01 12:09:00
# Old Project End:    2025-08-31 12:08:00  --  Old Budget End:    2025-08-31 12:08:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   240544
# New Award Amount:   40091
# Award Change:      -200453
# ---------------------------------------------------------------------------
#
#
# 5DP2AI164315-04 10675550
# UNIVERSITY OF CALIFORNIA-IRVINE
# One Ballroom: Understanding Intersectional Stigma to Optimize the HIV Prevention Continuum among Vulnerable Populations in the United States
# ---------------------------------------------------------------------------
# Project Start:      2021-09-24 12:09:00  --  Budget Start:      2023-09-01 12:09:00
# Old Project End:    2027-08-31 12:08:00  --  Old Budget End:    2025-08-31 12:08:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   426660
# New Award Amount:   1
# Award Change:      -426659
# ---------------------------------------------------------------------------
#
#
# 7DP2AI164315-03 10729776
# UNIVERSITY OF CALIFORNIA-IRVINE
# One Ballroom: Understanding Intersectional Stigma to Optimize the HIV Prevention Continuum among Vulnerable Populations in the United States
# ---------------------------------------------------------------------------
# Project Start:      2021-09-24 12:09:00  --  Budget Start:      2023-01-01 12:01:00
# Old Project End:    2026-08-31 12:08:00  --  Old Budget End:    2023-08-31 12:08:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2023-08-31 12:08:00
# ---------------------------------------------------------------------------
# Old Award Amount:   420678
# New Award Amount:   236415
# Award Change:      -184263
# ---------------------------------------------------------------------------

# %% [markdown]
# # 2. Retrieve entries where just the Project End has changed

# %% [markdown]
# It is likely that some projects were terminated after using up all of their funding. These projects will only have a date change. I separate them out from the previous category because when I look at date changes in the database, it is difficult to know whether a project had its end date moved up for legitimate reasons or whether a nefarious grant termination was involved.

# %%
data = duckdb.query(
    """
    SELECT new_data.date_added,
           new_data.appl_id,
           new_data.project_num,
           new_data.project_num_split.activity_code activity_code,
           new_data.project_title,
           new_data.organization.org_name,
           old_data.project_start_date,
           new_data.project_end_date new_project_end_date,
           old_data.project_end_date old_project_end_date,
           old_data.budget_start,
           new_data.budget_end new_budget_end_date,
           old_data.budget_end old_budget_end_date,
           new_data.award_amount new_award_amount,
           old_data.award_amount old_award_amount,
           new_data.award_amount - old_data.award_amount award_amount_change
    FROM read_json('../../../data/json/projects/year_added=202[345]/*/*') AS new_data
    INNER JOIN read_json('../../../data/json_2025_03_03/projects/year_added=202[345]/*/*') AS old_data
      ON new_data.appl_id = old_data.appl_id
    WHERE new_data.project_end_date < old_data.project_end_date
      AND new_award_amount = old_award_amount
      AND new_data.project_num_split.activity_code NOT LIKE 'F%'
    ORDER BY new_project_end_date DESC
    """
).to_df()

data.to_csv(
    "/home/jovyan/public/weekly/week_of_2025_03_09/data/project_changes_level_2_project_end_changes.csv",
    index=False
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
select = data.new_project_end_date >= datetime(2025, 1, 20)
for ind, row in data[select].iterrows():
    print(row.project_num, row.appl_id)
    print(row.org_name)
    print(row.project_title)
    print("-" * 75)
    print(f"Project Start:      {row.project_start_date}  --  Budget Start:      {row.budget_start}")
    print(f"Old Project End:    {row.old_project_end_date}  --  Old Budget End:    {row.old_budget_end_date}")
    print(f"New Project End:    {row.new_project_end_date}  --  New Budget End:    {row.new_budget_end_date}")
    print("-" * 75)
    print(f"Old Award Amount:   {row.old_award_amount}")
    print(f"New Award Amount:   {row.new_award_amount}")
    print(f"Award Change:       {row.new_award_amount - row.old_award_amount}")
    print("-" * 75)
    print("\n")
# Out:
# 5R01ES030616-05 10762347
# COLUMBIA UNIVERSITY HEALTH SCIENCES
# Integrating Air Pollution Prediction Models: Uncertainty Quantification and Propagation in Health Studies
# ---------------------------------------------------------------------------
# Project Start:      2020-03-16 12:03:00  --  Budget Start:      2024-01-01 12:01:00
# Old Project End:    2025-12-31 12:12:00  --  Old Budget End:    2025-12-31 12:12:00
# New Project End:    2025-06-30 12:06:00  --  New Budget End:    2025-06-30 12:06:00
# ---------------------------------------------------------------------------
# Old Award Amount:   601613
# New Award Amount:   601613
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10845589
# UNIVERSITY OF HOUSTON
# HEALTH Center for Addictions Research and Cancer Prevention
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2026-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   2512409
# New Award Amount:   2512409
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10845592
# UNIVERSITY OF HOUSTON
# RCMI Administrative Core
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   423430
# New Award Amount:   423430
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10845594
# UNIVERSITY OF HOUSTON
# RCMI Research Infrastructure Core
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   681093
# New Award Amount:   681093
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10845597
# UNIVERSITY OF HOUSTON
# RCMI Investigator Development Core
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   373291
# New Award Amount:   373291
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10845601
# UNIVERSITY OF HOUSTON
# RCMI Community Engagement Core
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   398244
# New Award Amount:   398244
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10845602
# UNIVERSITY OF HOUSTON
# Improving Access to Cigarette Cessation Treatment Among African American Smokers: Development and Evaluation of an Integrated mHealth Application
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   474784
# New Award Amount:   474784
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10897059
# UNIVERSITY OF HOUSTON
# Administrative Core
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   79351
# New Award Amount:   79351
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U54MD015946-05 10903815
# UNIVERSITY OF HOUSTON
# Administrative Core
# ---------------------------------------------------------------------------
# Project Start:      2020-09-08 12:09:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   82216
# New Award Amount:   82216
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01DK121812-05 10825514
# WAYNE STATE UNIVERSITY
# Regulation of Viscerosensory Sympathetic Reflexes: The Role of Diet-Derived Lipid Mediators.
# ---------------------------------------------------------------------------
# Project Start:      2020-04-01 12:04:00  --  Budget Start:      2024-04-01 12:04:00
# Old Project End:    2026-03-31 12:03:00  --  Old Budget End:    2026-03-31 12:03:00
# New Project End:    2025-03-31 12:03:00  --  New Budget End:    2025-03-31 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   416326
# New Award Amount:   416326
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5K23DC018022-05 10645154
# MASSACHUSETTS GENERAL HOSPITAL
# Role of Articulatory Motor Areas in Central Processing of Speech Sounds in Human Brain
# ---------------------------------------------------------------------------
# Project Start:      2019-07-01 12:07:00  --  Budget Start:      2023-07-01 12:07:00
# Old Project End:    2025-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-31 12:03:00  --  New Budget End:    2025-03-31 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   194972
# New Award Amount:   194972
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01MH104450-10 10778203
# UNIVERSITY OF WASHINGTON
# Phasic dopamine and symptom domains of mental illness
# ---------------------------------------------------------------------------
# Project Start:      2015-03-04 12:03:00  --  Budget Start:      2024-01-01 12:01:00
# Old Project End:    2025-12-31 12:12:00  --  Old Budget End:    2025-12-31 12:12:00
# New Project End:    2025-03-31 12:03:00  --  New Budget End:    2025-03-31 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   528412
# New Award Amount:   528412
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01CA249180-05 10809715
# UNIVERSITY OF FLORIDA
# Targeted degradation of RNAs by using small molecules
# ---------------------------------------------------------------------------
# Project Start:      2020-04-01 12:04:00  --  Budget Start:      2024-04-01 12:04:00
# Old Project End:    2026-03-31 12:03:00  --  Old Budget End:    2026-03-31 12:03:00
# New Project End:    2025-03-31 12:03:00  --  New Budget End:    2025-03-31 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   641325
# New Award Amount:   641325
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3U24MD017138-04S1 11100123
# MOREHOUSE SCHOOL OF MEDICINE
# FIRST Coordination and Evaluation Center to promote inclusive excellence
# ---------------------------------------------------------------------------
# Project Start:      2021-09-22 12:09:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2026-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-07 12:03:00  --  New Budget End:    2025-03-07 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   161636
# New Award Amount:   161636
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5U24MD017138-04 10892031
# MOREHOUSE SCHOOL OF MEDICINE
# FIRST Coordination and Evaluation Center  to promote inclusive excellence
# ---------------------------------------------------------------------------
# Project Start:      2021-09-22 12:09:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2026-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-07 12:03:00  --  New Budget End:    2025-03-07 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   2050196
# New Award Amount:   2050196
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 1R41MD019548-01 10918693
# OLIPHA INC
# A Biobased Biodegradable Sunscreen that is Safe, Removes Environmental Impact, is Inclusive of all Skin Tones, and is for the Purpose of Eliminating Disparities in Melanoma Mortality Rates
# ---------------------------------------------------------------------------
# Project Start:      2024-08-18 12:08:00  --  Budget Start:      2024-08-18 12:08:00
# Old Project End:    2025-07-31 12:07:00  --  Old Budget End:    2025-07-31 12:07:00
# New Project End:    2025-03-04 12:03:00  --  New Budget End:    2025-03-04 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   293629
# New Award Amount:   293629
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01HD098233-05 10619517
# UNIVERSITY OF MICHIGAN AT ANN ARBOR
# Reproductive Consequences of Steroid Hormone Administration
# ---------------------------------------------------------------------------
# Project Start:      2019-05-01 12:05:00  --  Budget Start:      2023-05-01 12:05:00
# Old Project End:    2025-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   532185
# New Award Amount:   532185
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01AG037031-14 10898566
# PEKING UNIVERSITY
# China Health and Retirement Longitudinal study
# ---------------------------------------------------------------------------
# Project Start:      2020-06-15 12:06:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2025-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   1739936
# New Award Amount:   1739936
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01AI150533-05 10810800
# CHINA MEDICAL UNIVERSITY
# Antigen discovery for transmission-blocking vaccines in Plasmodium vivax
# ---------------------------------------------------------------------------
# Project Start:      2020-04-06 12:04:00  --  Budget Start:      2024-04-01 12:04:00
# Old Project End:    2025-03-31 12:03:00  --  Old Budget End:    2025-03-31 12:03:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   135000
# New Award Amount:   135000
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 1R43AG090173-01 11007685
# RHAEOS, INC.
# Development of wearable sensors for continuous wound monitoring
# ---------------------------------------------------------------------------
# Project Start:      2024-09-15 12:09:00  --  Budget Start:      2024-09-15 12:09:00
# Old Project End:    2025-03-31 12:03:00  --  Old Budget End:    2025-03-31 12:03:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   306522
# New Award Amount:   306522
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01CA235589-05 10687096
# BRIGHAM AND WOMEN'S HOSPITAL
# Lymph Node Quantification System for Multisite Clinical Trials
# ---------------------------------------------------------------------------
# Project Start:      2019-09-01 12:09:00  --  Budget Start:      2023-09-01 12:09:00
# Old Project End:    2025-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   595794
# New Award Amount:   595794
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5SC3GM136580-04 10701731
# HUNTER COLLEGE
# Trajectories of Adaptation to Traumatic Stress in a Vulnerable Population
# ---------------------------------------------------------------------------
# Project Start:      2020-09-01 12:09:00  --  Budget Start:      2023-09-01 12:09:00
# Old Project End:    2025-08-31 12:08:00  --  Old Budget End:    2025-08-31 12:08:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   117000
# New Award Amount:   117000
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5UG3DE030063-02 10769887
# HEALTHPARTNERS INSTITUTE
# Investigating Behavioral Mechanisms and Efficacy of a Provider-Directed Intervention for HPV Vaccine Promotion in Real-World Dental Settings
# ---------------------------------------------------------------------------
# Project Start:      2023-02-01 12:02:00  --  Budget Start:      2024-02-01 12:02:00
# Old Project End:    2026-01-31 12:01:00  --  Old Budget End:    2026-01-31 12:01:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   363322
# New Award Amount:   363322
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5K99CA279888-02 10890035
# DANA-FARBER CANCER INST
# Targeting Menin Protein Stability In AML
# ---------------------------------------------------------------------------
# Project Start:      2023-07-18 12:07:00  --  Budget Start:      2024-04-01 12:04:00
# Old Project End:    2025-03-31 12:03:00  --  Old Budget End:    2025-03-31 12:03:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   129600
# New Award Amount:   129600
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5K01AG078126-03 10870207
# YALE UNIVERSITY
# Revealing roles of heterosynaptic plasticity in Alzheimer's disease
# ---------------------------------------------------------------------------
# Project Start:      2022-08-15 12:08:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2027-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-02-14 12:02:00  --  New Budget End:    2025-02-14 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   144418
# New Award Amount:   144418
# Award Change:       0
# ---------------------------------------------------------------------------

# %% [markdown]
# # 3. Retrieve F grant entries where the Project End has changed

# %% [markdown]
# As mentioned above, I believe it can be difficult to determine which grants under this list had project end changes because of the current administation and which grants had individuals graduate. Therefore, I am a more cautious with the filtering on this list.

# %%
data = duckdb.query(
    """
    SELECT new_data.date_added,
           new_data.appl_id,
           new_data.project_num,
           new_data.project_num_split.activity_code activity_code,
           new_data.project_title,
           new_data.organization.org_name,
           old_data.project_start_date,
           new_data.project_end_date new_project_end_date,
           old_data.project_end_date old_project_end_date,
           old_data.budget_start,
           new_data.budget_end new_budget_end_date,
           old_data.budget_end old_budget_end_date,
           new_data.award_amount new_award_amount,
           old_data.award_amount old_award_amount,
           new_data.award_amount - old_data.award_amount award_amount_change
    FROM read_json('../../../data/json/projects/year_added=202[345]/*/*') AS new_data
    INNER JOIN read_json('../../../data/json_2025_03_03/projects/year_added=202[345]/*/*') AS old_data
      ON new_data.appl_id = old_data.appl_id
    WHERE new_data.project_end_date < old_data.project_end_date
      AND new_data.project_num_split.activity_code LIKE 'F%'
      AND new_data.project_end_date >= '2025-01-20'
    ORDER BY new_project_end_date DESC
    """
).to_df()

data.to_csv(
    "/home/jovyan/public/weekly/week_of_2025_03_09/data/project_changes_level_3_training_grant_changes.csv",
    index=False
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
select = data.new_project_end_date >= datetime(2025, 1, 20)
for ind, row in data[select].iterrows():
    print(row.project_num, row.appl_id)
    print(row.org_name)
    print(row.project_title)
    print("-" * 75)
    print(f"Project Start:      {row.project_start_date}  --  Budget Start:      {row.budget_start}")
    print(f"Old Project End:    {row.old_project_end_date}  --  Old Budget End:    {row.old_budget_end_date}")
    print(f"New Project End:    {row.new_project_end_date}  --  New Budget End:    {row.new_budget_end_date}")
    print("-" * 75)
    print(f"Old Award Amount:   {row.old_award_amount}")
    print(f"New Award Amount:   {row.new_award_amount}")
    print(f"Award Change:       {row.new_award_amount - row.old_award_amount}")
    print("-" * 75)
    print("\n")
# Out:
# 5F31HD112236-02 10814787
# UNIVERSITY OF WASHINGTON
# Planning for delivery of novel PrEP formulations to pregnant and postpartum women in Kenya
# ---------------------------------------------------------------------------
# Project Start:      2023-06-15 12:06:00  --  Budget Start:      2024-06-15 12:06:00
# Old Project End:    2026-06-14 12:06:00  --  Old Budget End:    2025-06-14 12:06:00
# New Project End:    2025-03-31 12:03:00  --  New Budget End:    2025-03-31 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   48780
# New Award Amount:   43050
# Award Change:       -5730
# ---------------------------------------------------------------------------
#
#
# 1F31GM153136-01 10826027
# JOHNS HOPKINS UNIVERSITY
# Understanding how chromosomal makeup and cross-sex hormone administration affect wound healing in mice
# ---------------------------------------------------------------------------
# Project Start:      2024-06-01 12:06:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2027-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   48974
# New Award Amount:   48974
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5F31HL172648-02 11074016
# UNIVERSITY OF MISSISSIPPI MED CTR
# Cross Sex Steroid Therapy and Cardiovascular Risk in the Transgender Female
# ---------------------------------------------------------------------------
# Project Start:      2023-12-01 12:12:00  --  Budget Start:      2024-12-01 12:12:00
# Old Project End:    2026-11-30 12:11:00  --  Old Budget End:    2025-11-30 12:11:00
# New Project End:    2025-03-03 12:03:00  --  New Budget End:    2025-03-03 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   32974
# New Award Amount:   2124
# Award Change:       -30850
# ---------------------------------------------------------------------------
#
#
# 5F30HD112110-02 10860962
# UNIVERSITY OF PITTSBURGH AT PITTSBURGH
# Relationships Between Pain-Related Psychological Factors, Gait Quality, and Attention in Chronic Low Back Pain
# ---------------------------------------------------------------------------
# Project Start:      2023-06-01 12:06:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2025-11-12 12:11:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-02-12 12:02:00  --  New Budget End:    2025-02-12 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   46400
# New Award Amount:   37928
# Award Change:       -8472
# ---------------------------------------------------------------------------
#
#
# 5F31HL170563-02 10910879
# UNIVERSITY OF DELAWARE
# Sex Differences in Central Neural Activation During Acute Hypernatremia
# ---------------------------------------------------------------------------
# Project Start:      2023-08-01 12:08:00  --  Budget Start:      2024-08-01 12:08:00
# Old Project End:    2026-07-31 12:07:00  --  Old Budget End:    2025-07-31 12:07:00
# New Project End:    2025-02-09 12:02:00  --  New Budget End:    2025-02-09 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   44172
# New Award Amount:   20589
# Award Change:       -23583
# ---------------------------------------------------------------------------
