# %%
import duckdb
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from datetime import datetime, timedelta

# %% [markdown]
# # 1. Retrieve entries where the Project End and Award Amount have changed

# %% [markdown]
# This first set of data focuses on grants which do not have an activity code that starts with F. Later on in this notebook, I pull out F grants, but I believe some date and funding changes for F type grants may reflect graduations. Date and funding changes for non-training grants may be rarer.

# %%
data = duckdb.query(
    """
    SELECT new_data.date_added,
           new_data.appl_id,
           new_data.project_num,
           new_data.project_num_split.activity_code activity_code,
           new_data.project_title,
           new_data.organization.org_name,
           old_data.project_start_date,
           new_data.project_end_date new_project_end_date,
           old_data.project_end_date old_project_end_date,
           old_data.budget_start,
           new_data.budget_end new_budget_end_date,
           old_data.budget_end old_budget_end_date,
           new_data.award_amount new_award_amount,
           old_data.award_amount old_award_amount,
           new_data.award_amount - old_data.award_amount award_amount_change
    FROM read_json('../../../data/json/projects/year_added=202[345]/*/*') AS new_data
    INNER JOIN read_json('../../../data/json_2025_03_30/projects/year_added=202[345]/*/*') AS old_data
      ON new_data.appl_id = old_data.appl_id
    WHERE new_data.project_end_date < old_data.project_end_date
      AND new_award_amount < old_award_amount
      AND new_data.project_num_split.activity_code NOT LIKE 'F%'
    ORDER BY new_project_end_date DESC
    """
).to_df()

data.to_csv(
    "/home/jovyan/public/weekly/week_of_2025_04_06/data/project_changes_level_1_project_end_and_award_changes.csv",
    index=False
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %% [markdown]
# For convenience, below I will write out the projects which have new project end dates after the last innauguration in a more human readable format.

# %%
select = data.new_project_end_date >= datetime(2025, 1, 20)
for ind, row in data[select].iterrows():
    print(row.project_num, row.appl_id)
    print(row.org_name)
    print(row.project_title)
    print("-" * 75)
    print(f"Project Start:      {row.project_start_date}  --  Budget Start:      {row.budget_start}")
    print(f"Old Project End:    {row.old_project_end_date}  --  Old Budget End:    {row.old_budget_end_date}")
    print(f"New Project End:    {row.new_project_end_date}  --  New Budget End:    {row.new_budget_end_date}")
    print("-" * 75)
    print(f"Old Award Amount:   {row.old_award_amount}")
    print(f"New Award Amount:   {row.new_award_amount}")
    print(f"Award Change:      {row.new_award_amount - row.old_award_amount}")
    print("-" * 75)
    print("\n")
# Out:
# 5UG1CA190000-11 10900452
# HEKTOEN INSTITUTE FOR MEDICAL RESEARCH
# Stroger Hospital of Cook County (SHCC) MU-NCORP Renewal
# ---------------------------------------------------------------------------
# Project Start:      2014-08-16 12:08:00  --  Budget Start:      2024-08-01 12:08:00
# Old Project End:    2025-07-31 12:07:00  --  Old Budget End:    2025-07-31 12:07:00
# New Project End:    2025-03-31 12:03:00  --  New Budget End:    2025-03-31 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   758182
# New Award Amount:   410325
# Award Change:      -347857
# ---------------------------------------------------------------------------
#
#
# 3R01AI172066-03S1 11117358
# UNIVERSITY OF CENTRAL FLORIDA
# Plasmodium Protein Kinase Focused Antimalarials Discovery
# ---------------------------------------------------------------------------
# Project Start:      2022-07-11 12:07:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2027-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-11 12:03:00  --  New Budget End:    2025-03-11 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   58225
# New Award Amount:   46379
# Award Change:      -11846
# ---------------------------------------------------------------------------
#
#
# 5R35GM150868-02 10915645
# UNIVERSITY OF NOTRE DAME
# Protein Structure, Dynamics, and Aggregation in Phase Separated Droplets
# ---------------------------------------------------------------------------
# Project Start:      2023-09-01 12:09:00  --  Budget Start:      2024-09-01 12:09:00
# Old Project End:    2028-08-31 12:08:00  --  Old Budget End:    2025-08-31 12:08:00
# New Project End:    2025-02-01 12:02:00  --  New Budget End:    2025-02-01 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   391250
# New Award Amount:   1
# Award Change:      -391249
# ---------------------------------------------------------------------------
#
#
# 1R01AR082944-01A1 10881086
# THOMAS JEFFERSON UNIVERSITY
# The role of collagen VII in extracellular matrix protein secretion
# ---------------------------------------------------------------------------
# Project Start:      2024-06-01 12:06:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2029-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-01-30 12:01:00  --  New Budget End:    2025-01-30 12:01:00
# ---------------------------------------------------------------------------
# Old Award Amount:   343200
# New Award Amount:   227518
# Award Change:      -115682
# ---------------------------------------------------------------------------

# %% [markdown]
# # 2. Retrieve entries where just the Project End has changed

# %% [markdown]
# It is likely that some projects were terminated after using up all of their funding. These projects will only have a date change. I separate them out from the previous category because when I look at date changes in the database, it is difficult to know whether a project had its end date moved up for legitimate reasons or whether a nefarious grant termination was involved.

# %%
data = duckdb.query(
    """
    SELECT new_data.date_added,
           new_data.appl_id,
           new_data.project_num,
           new_data.project_num_split.activity_code activity_code,
           new_data.project_title,
           new_data.organization.org_name,
           old_data.project_start_date,
           new_data.project_end_date new_project_end_date,
           old_data.project_end_date old_project_end_date,
           old_data.budget_start,
           new_data.budget_end new_budget_end_date,
           old_data.budget_end old_budget_end_date,
           new_data.award_amount new_award_amount,
           old_data.award_amount old_award_amount,
           new_data.award_amount - old_data.award_amount award_amount_change
    FROM read_json('../../../data/json/projects/year_added=202[345]/*/*') AS new_data
    INNER JOIN read_json('../../../data/json_2025_03_30/projects/year_added=202[345]/*/*') AS old_data
      ON new_data.appl_id = old_data.appl_id
    WHERE new_data.project_end_date < old_data.project_end_date
      AND new_award_amount = old_award_amount
      AND new_data.project_num_split.activity_code NOT LIKE 'F%'
    ORDER BY new_project_end_date DESC
    """
).to_df()

data.to_csv(
    "/home/jovyan/public/weekly/week_of_2025_04_06/data/project_changes_level_2_project_end_changes.csv",
    index=False
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
select = np.logical_and(
    data.new_project_end_date >= datetime(2025, 1, 20),
    data.new_project_end_date <= datetime(2025, 6, 30)
)
data[select].groupby("org_name").appl_id.count().sort_values(ascending=False)
# Out:
# org_name
# STANFORD UNIVERSITY                       7
# UNIVERSITY OF CALIFORNIA, SAN DIEGO       4
# NORTHEASTERN UNIVERSITY                   2
# UNIVERSITY OF MINNESOTA                   2
# UNIVERSITY OF CALIFORNIA-IRVINE           2
#                                          ..
# UNIVERSITY OF WASHINGTON                  1
# VANDERBILT UNIVERSITY MEDICAL CENTER      1
# WAKE FOREST UNIVERSITY HEALTH SCIENCES    1
# WETA TV 26                                1
# WORCESTER POLYTECHNIC INSTITUTE           1
# Name: appl_id, Length: 104, dtype: int64

# %%
select = np.logical_and(
    data.new_project_end_date >= datetime(2025, 1, 20),
    data.new_project_end_date <= datetime(2025, 6, 30)
)
print(
    f"Displaying {sum(select)} projects with changes"
)
print()
for ind, row in data[select].iterrows():
    print(row.project_num, row.appl_id)
    print(row.org_name)
    print(row.project_title)
    print("-" * 75)
    print(f"Project Start:      {row.project_start_date}  --  Budget Start:      {row.budget_start}")
    print(f"Old Project End:    {row.old_project_end_date}  --  Old Budget End:    {row.old_budget_end_date}")
    print(f"New Project End:    {row.new_project_end_date}  --  New Budget End:    {row.new_budget_end_date}")
    print("-" * 75)
    print(f"Old Award Amount:   {row.old_award_amount}")
    print(f"New Award Amount:   {row.new_award_amount}")
    print(f"Award Change:       {row.new_award_amount - row.old_award_amount}")
    print("-" * 75)
    print("\n")
# Out:
# Displaying 120 projects with changes
#
# 3U01DA054170-04S2 11123762
# UNIVERSITY OF TEXAS SAN ANTONIO
# Spatial analyses of marmoset germline development
# ---------------------------------------------------------------------------
# Project Start:      2021-08-01 12:08:00  --  Budget Start:      2024-06-22 12:06:00
# Old Project End:    2026-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-05-31 12:05:00  --  New Budget End:    2025-05-31 12:05:00
# ---------------------------------------------------------------------------
# Old Award Amount:   26685
# New Award Amount:   26685
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3DP1DA054344-03S1 11075595
# OHIO STATE UNIVERSITY
# X chromosome inactivation in sex disparities to substance use disorder
# ---------------------------------------------------------------------------
# Project Start:      2021-08-15 12:08:00  --  Budget Start:      2024-09-01 12:09:00
# Old Project End:    2027-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-05-31 12:05:00  --  New Budget End:    2025-05-31 12:05:00
# ---------------------------------------------------------------------------
# Old Award Amount:   84500
# New Award Amount:   84500
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01NR020008-02 10620786
# UNIVERSITY OF COLORADO DENVER
# Randomized Clinical Trial of Nurse Family Partnership for Women with Previous Live Births
# ---------------------------------------------------------------------------
# Project Start:      2022-05-11 12:05:00  --  Budget Start:      2023-03-01 12:03:00
# Old Project End:    2027-02-28 12:02:00  --  Old Budget End:    2025-02-28 12:02:00
# New Project End:    2025-05-31 12:05:00  --  New Budget End:    2025-05-31 12:05:00
# ---------------------------------------------------------------------------
# Old Award Amount:   761518
# New Award Amount:   761518
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA056499-03S1 10976011
# UNIVERSITY OF MINNESOTA
# Leveraging quasi-experimental methods to examine the longitudinal relations among legal system exposure, substance use, neurocognition, and education
# ---------------------------------------------------------------------------
# Project Start:      2022-07-01 12:07:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2027-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-05-31 12:05:00  --  New Budget End:    2025-05-31 12:05:00
# ---------------------------------------------------------------------------
# Old Award Amount:   196129
# New Award Amount:   196129
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA054220-04S1 11056994
# NEW YORK UNIVERSITY SCHOOL OF MEDICINE
# SOAR: Smartphones for Opioid Addiction Recovery
# ---------------------------------------------------------------------------
# Project Start:      2021-08-15 12:08:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2026-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-05-31 12:05:00  --  New Budget End:    2025-05-31 12:05:00
# ---------------------------------------------------------------------------
# Old Award Amount:   158414
# New Award Amount:   158414
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA051127-04S1 11056941
# UNIV OF NORTH CAROLINA CHAPEL HILL
# Neurobiological susceptibility to peer influence and drug use in adolescence
# ---------------------------------------------------------------------------
# Project Start:      2020-07-01 12:07:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2026-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-05-31 12:05:00  --  New Budget End:    2025-05-31 12:05:00
# ---------------------------------------------------------------------------
# Old Award Amount:   114963
# New Award Amount:   114963
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01CA249096-04 10755703
# UNIVERSITY OF MICHIGAN AT ANN ARBOR
# New Statistical Methods for Modelling Cancer Outcomes
# ---------------------------------------------------------------------------
# Project Start:      2021-01-01 12:01:00  --  Budget Start:      2024-01-01 12:01:00
# Old Project End:    2025-12-31 12:12:00  --  Old Budget End:    2025-12-31 12:12:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   325366
# New Award Amount:   325366
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA056602-03S1 11075487
# UNIVERSITY OF CALIFORNIA, SAN DIEGO
# Multiomic profiling of cell types mediating opioid use disorder in rats
# ---------------------------------------------------------------------------
# Project Start:      2022-08-15 12:08:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2027-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   129280
# New Award Amount:   129280
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA055673-03S1 11052925
# UNIVERSITY OF CALIFORNIA, SAN DIEGO
# Exploring the accessibility, acceptability, and utilization of a community-based harm reduction vending machine among persons with limited opportunity structures.
# ---------------------------------------------------------------------------
# Project Start:      2022-06-15 12:06:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2027-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   179852
# New Award Amount:   179852
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3DP2AI154420-04S1 10950478
# UNIVERSITY OF CALIFORNIA-IRVINE
# Connecting the Spatiotemporal Organization of Gut Bacterial Communities to the Emergence and Spread of Antibiotic Resistance
# ---------------------------------------------------------------------------
# Project Start:      2021-05-05 12:05:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-30 12:04:00  --  New Budget End:    2025-04-30 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   82025
# New Award Amount:   82025
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 1K99LM014614-01 10950095
# YALE UNIVERSITY
# Reliable Question-Answering Frameworks for Clinical Decision Support using Domain-specific Large Language Models
# ---------------------------------------------------------------------------
# Project Start:      2024-09-01 12:09:00  --  Budget Start:      2024-09-01 12:09:00
# Old Project End:    2025-08-31 12:08:00  --  Old Budget End:    2025-08-31 12:08:00
# New Project End:    2025-04-15 12:04:00  --  New Budget End:    2025-04-15 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   88034
# New Award Amount:   88034
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01EB031008-04 10752710
# MASSACHUSETTS GENERAL HOSPITAL
# Artificial Intelligence Boosted Evolution and Detection of Genetically Encoded Reporters for In Vivo Imaging
# ---------------------------------------------------------------------------
# Project Start:      2021-04-01 12:04:00  --  Budget Start:      2024-01-01 12:01:00
# Old Project End:    2025-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-04-09 12:04:00  --  New Budget End:    2025-04-09 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   620343
# New Award Amount:   620343
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R61AI167035-03 10760292
# UNIVERSITY OF ROCHESTER
# Paper-based HIV self test
# ---------------------------------------------------------------------------
# Project Start:      2022-01-25 12:01:00  --  Budget Start:      2024-01-01 12:01:00
# Old Project End:    2025-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-04-09 12:04:00  --  New Budget End:    2025-04-09 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   444317
# New Award Amount:   444317
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01MD016882-04 10759403
# NORTHEASTERN UNIVERSITY
# Community-based Design and Evaluation of a Conversational Agent to Promote SARS-COV2 Vaccination in Black Churches
# ---------------------------------------------------------------------------
# Project Start:      2021-04-23 12:04:00  --  Budget Start:      2024-02-01 12:02:00
# Old Project End:    2026-01-31 12:01:00  --  Old Budget End:    2026-01-31 12:01:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:
00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   241234
# New Award Amount:   241234
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5K22CA258675-03 10923996
# RUTGERS BIOMEDICAL AND HEALTH SCIENCES
# Addressing HPV vaccination disparities through tailored messaging for hesitant families
# ---------------------------------------------------------------------------
# Project Start:      2022-08-02 12:08:00  --  Budget Start:      2024-08-01 12:08:00
# Old Project End:    2025-07-31 12:07:00  --  Old Budget End:    2025-07-31 12:07:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   219899
# New Award Amount:   219899
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01MD017364-03 10771048
# JOHNS HOPKINS UNIVERSITY
# REDES: a peer network and mobile health (mHealth) enhanced CHW model to maximize COVID-19 vaccination among low income Latinos
# ---------------------------------------------------------------------------
# Project Start:      2022-04-13 12:04:00  --  Budget Start:      2024-01-01 12:01:00
# Old Project End:    2027-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   714762
# New Award Amount:   714762
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 7R01MD019024-02 10908996
# WAKE FOREST UNIVERSITY HEALTH SCIENCES
# Advancing communication strategies to support future HIV vaccine use among African Americans in the South.
# ---------------------------------------------------------------------------
# Project Start:      2023-08-17 12:08:00  --  Budget Start:      2024-04-17 12:04:00
# Old Project End:    2028-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   766932
# New Award Amount:   766932
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01AR080089-03 10840830
# NORTHWESTERN UNIVERSITY AT CHICAGO
# Leveraging Community-Academic Partnerships and Social Networks to Disseminate Vaccine-Related Information and Increase Vaccine Uptake Among Black Individuals with Rheumatic Diseases
# ---------------------------------------------------------------------------
# Project Start:      2022-05-10 12:05:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2027-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   709413
# New Award Amount:   709413
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R37CA253279-05 10842257
# PENNSYLVANIA STATE UNIV HERSHEY MED CTR
# HPV ECHO: Increasing the adoption of evidence-based communication strategies for HPV vaccination in rural primary care practices
# ---------------------------------------------------------------------------
# Project Start:      2020-08-10 12:08:00  --  Budget Start:      2024-05-01 12:05:00
# Old Project End:    2025-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   351690
# New Award Amount:   351690
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 7R01DA054990-04 11094263
# NDRI-USA, INC.
# Community Developed Technology-Based Messaging to Increase SARS-CoV-2 Vaccine Uptake Among People Who Inject Drugs
# ---------------------------------------------------------------------------
# Project Start:      2021-06-01 12:06:00  --  Budget Start:      2024-05-24 12:05:00
# Old Project End:    2026-04-30 12:04:00  --  Old Budget End:    2026-04-30 12:04:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   461653
# New Award Amount:   461653
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5K01AG065440-05 10849875
# UNIVERSITY OF IOWA
# Creating Innovative Vaccine Messaging by Engaging in Patient-Centered Design with Non-Vaccinating Older Adults
# ---------------------------------------------------------------------------
# Project Start:      2020-08-01 12:08:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2025-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   122211
# New Award Amount:   122211
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R25GM150142-02 10880678
# UNIVERSITY OF IDAHO
# Eradicating Misconceptions about Viruses using Multimodal Trace Data in an Intelligent Game-based Environment across Educational Contexts
# ---------------------------------------------------------------------------
# Project Start:      2023-07-03 12:07:00  --  Budget Start:      2024-06-01 12:06:00
# Old Project End:    2028-05-31 12:05:00  --  Old Budget End:    2025-05-31 12:05:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   261005
# New Award Amount:   261005
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 1R01MD019765-01 10946664
# UNIVERSITY OF CALIFORNIA-IRVINE
# Influence of Social Media, Social Networks, and Misinformation on Vaccine Acceptance Among Black and Latinx Individuals
# ---------------------------------------------------------------------------
# Project Start:      2024-09-20 12:09:00  --  Budget Start:      2024-09-20 12:09:00
# Old Project End:    2029-04-30 12:04:00  --  Old Budget End:    2025-04-30 12:04:00
# New Project End:    2025-04-01 12:04:00  --  New Budget End:    2025-04-01 12:04:00
# ---------------------------------------------------------------------------
# Old Award Amount:   683352
# New Award Amount:   683352
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 
06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-14 12:03:00  --  New Budget End:    2025-03-14 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   1444263
# New Award Amount:   1444263
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3U01DA051234-04S1 10982894
# UNIVERSITY OF CALIFORNIA, SAN DIEGO
# Characterization of Tandem Repeat and Structural Variants Contributing to Addictive Behaviors in Mice and Rats
# ---------------------------------------------------------------------------
# Project Start:      2021-05-01 12:05:00  --  Budget Start:      2024-03-01 12:03:00
# Old Project End:    2026-02-28 12:02:00  --  Old Budget End:    2025-02-28 12:02:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   116869
# New Award Amount:   116869
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5K23HL166691-02 10894889
# DUKE UNIVERSITY
# Implementation of a Medication Adherence Instrument among Patients with Symptomatic Peripheral Artery Disease after Peripheral Vascular Intervention
# ---------------------------------------------------------------------------
# Project Start:      2023-07-27 12:07:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2028-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   165526
# New Award Amount:   165526
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA057789-02S1 11086406
# YALE UNIVERSITY
# Substance use disorder treatment centers and facility ownership changes
# ---------------------------------------------------------------------------
# Project Start:      2023-04-01 12:04:00  --  Budget Start:      2024-03-01 12:03:00
# Old Project End:    2027-02-28 12:02:00  --  Old Budget End:    2025-02-28 12:02:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   49799
# New Award Amount:   49799
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5R01DK123043-04 10643873
# UNIVERSITY OF IOWA
# UCP1 and the regulation of mitochondrial respiration in brown adipose tissue by oxaloacetate
# ---------------------------------------------------------------------------
# Project Start:      2020-09-15 12:09:00  --  Budget Start:      2023-07-01 12:07:00
# Old Project End:    2025-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-02-28 12:02:00  --  New Budget End:    2025-02-28 12:02:00
# ---------------------------------------------------------------------------
# Old Award Amount:   315000
# New Award Amount:   315000
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 3R01DA055839-02S1 10988074
# UNIVERSITY OF SOUTHERN CALIFORNIA
# The influence of social stress on polysubstance use and addiction vulnerability among adults in communities of color: The mediating role of psychological pain
# ---------------------------------------------------------------------------
# Project Start:      2023-04-15 12:04:00  --  Budget Start:      2024-02-01 12:02:00
# Old Project End:    2026-01-31 12:01:00  --  Old Budget End:    2025-01-31 12:01:00
# New Project End:    2025-01-31 12:01:00  --  New Budget End:    2025-01-31 12:01:00
# ---------------------------------------------------------------------------
# Old Award Amount:   63001
# New Award Amount:   63001
# Award Change:       0
# ---------------------------------------------------------------------------

# %% [markdown]
# # 3. Retrieve F grant entries where the Project End has changed

# %% [markdown]
# As mentioned above, I believe it can be difficult to determine which grants under this list had project end changes because of the current administation and which grants had individuals graduate. Therefore, I am a more cautious with the filtering on this list.

# %%
data = duckdb.query(
    """
    SELECT new_data.date_added,
           new_data.appl_id,
           new_data.project_num,
           new_data.project_num_split.activity_code activity_code,
           new_data.project_title,
           new_data.organization.org_name,
           old_data.project_start_date,
           new_data.project_end_date new_project_end_date,
           old_data.project_end_date old_project_end_date,
           old_data.budget_start,
           new_data.budget_end new_budget_end_date,
           old_data.budget_end old_budget_end_date,
           new_data.award_amount new_award_amount,
           old_data.award_amount old_award_amount,
           new_data.award_amount - old_data.award_amount award_amount_change
    FROM read_json('../../../data/json/projects/year_added=202[345]/*/*') AS new_data
    INNER JOIN read_json('../../../data/json_2025_03_30/projects/year_added=202[345]/*/*') AS old_data
      ON new_data.appl_id = old_data.appl_id
    WHERE new_data.project_end_date < old_data.project_end_date
      AND new_data.project_num_split.activity_code LIKE 'F%'
      AND new_data.project_end_date >= '2025-01-20'
    ORDER BY new_project_end_date DESC
    """
).to_df()

data.to_csv(
    "/home/jovyan/public/weekly/week_of_2025_04_06/data/project_changes_level_3_training_grant_changes.csv",
    index=False
)
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
select = np.logical_and(
    data.new_project_end_date >= datetime(2025, 1, 20),
    data.new_project_end_date <= datetime(2025, 6, 30)
)
print(
    f"Displaying {sum(select)} projects with changes"
)
print()
for ind, row in data[select].iterrows():
    print(row.project_num, row.appl_id)
    print(row.org_name)
    print(row.project_title)
    print("-" * 75)
    print(f"Project Start:      {row.project_start_date}  --  Budget Start:      {row.budget_start}")
    print(f"Old Project End:    {row.old_project_end_date}  --  Old Budget End:    {row.old_budget_end_date}")
    print(f"New Project End:    {row.new_project_end_date}  --  New Budget End:    {row.new_budget_end_date}")
    print("-" * 75)
    print(f"Old Award Amount:   {row.old_award_amount}")
    print(f"New Award Amount:   {row.new_award_amount}")
    print(f"Award Change:       {row.new_award_amount - row.old_award_amount}")
    print("-" * 75)
    print("\n")
# Out:
# Displaying 4 projects with changes
#
# 1F31MH134720-01A1 10923472
# MEDICAL COLLEGE OF WISCONSIN
# Understanding Patient Level Implementation Determinants Related to Long-acting Injectable HIV Pre-Exposure Prophylaxis among Young Men Who Have Sex with Men Living in Rural Areas
# ---------------------------------------------------------------------------
# Project Start:      2024-07-01 12:07:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2027-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-18 12:03:00  --  New Budget End:    2025-03-18 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   48974
# New Award Amount:   48974
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5F31HD108988-03 10814868
# EMORY UNIVERSITY
# Neurophysiologic correlates of training-induced locomotor learning post-stroke
# ---------------------------------------------------------------------------
# Project Start:      2022-04-01 12:04:00  --  Budget Start:      2024-04-01 12:04:00
# Old Project End:    2025-03-31 12:03:00  --  Old Budget End:    2025-03-31 12:03:00
# New Project End:    2025-03-16 12:03:00  --  New Budget End:    2025-03-16 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   48974
# New Award Amount:   47798
# Award Change:       -1176
# ---------------------------------------------------------------------------
#
#
# 5F32AG081117-02 10816433
# RICE UNIVERSITY
# Estrogen Declines with Menopause: Impacts on the Medial Temporal Lobe Network and Emotional Memory in Aging Females at Genetic Risk for Alzheimer’s Disease
# ---------------------------------------------------------------------------
# Project Start:      2023-03-16 12:03:00  --  Budget Start:      2024-03-16 12:03:00
# Old Project End:    2026-03-15 12:03:00  --  Old Budget End:    2025-03-15 12:03:00
# New Project End:    2025-03-15 12:03:00  --  New Budget End:    2025-03-15 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   78328
# New Award Amount:   78328
# Award Change:       0
# ---------------------------------------------------------------------------
#
#
# 5F31AI172316-03 10886817
# COLUMBIA UNIVERSITY HEALTH SCIENCES
# A Novel Long Noncoding RNA Associated with Systemic Lupus Erythematosus Pathogenesis
# ---------------------------------------------------------------------------
# Project Start:      2022-07-01 12:07:00  --  Budget Start:      2024-07-01 12:07:00
# Old Project End:    2025-06-30 12:06:00  --  Old Budget End:    2025-06-30 12:06:00
# New Project End:    2025-03-13 12:03:00  --  New Budget End:    2025-03-13 12:03:00
# ---------------------------------------------------------------------------
# Old Award Amount:   48974
# New Award Amount:   48974
# Award Change:       0
# ---------------------------------------------------------------------------
